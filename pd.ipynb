# %% [markdown]
# <H1>PANDAS</H1>

# %% [markdown]
# <h4>pandas objects can be thought of as enhanced versions of numpy structured arrays in which rows and columns are identified with rather than simple integer indices.</h4>

# %%
import numpy as np 
import pandas as pd

# %% [markdown]
# Pandas Series Object

# %%
data = pd.Series([0.25,0.5,0.75,1.0])
data
# Out:
# 0    0.25
# 1    0.50
# 2    0.75
# 3    1.00
# dtype: float64

# %%
data.values, data.index, data[1], data[1:3]
# Out:
# (array([0.25, 0.5 , 0.75, 1.  ]),
#  RangeIndex(start=0, stop=4, step=1),
#  np.float64(0.5),
#  1    0.50
#  2    0.75
#  dtype: float64)

# %%
data = pd.Series([0.25, 0.5, 0.75, 1.0], index=['a','b','c','d'])
data, data['b']
# Out:
# (a    0.25
#  b    0.50
#  c    0.75
#  d    1.00
#  dtype: float64,
#  np.float64(0.5))

# %%
data[(data > 0.3) & (data < 0.8)] #masking/
# Out:
# b    0.50
# c    0.75
# dtype: float64

# %%
# fancy indexing
data[['a', 'd']]
# Out:
# a    0.25
# d    1.00
# dtype: float64

# %%
data = pd.Series(['a', 'b', 'c'], index=[1, 3, 5])
data
# Out:
# 1    a
# 3    b
# 5    c
# dtype: str

# %%
data[1], data[1:3], data.loc[1], data.iloc[1:3]
# Out:
# ('a',
#  3    b
#  5    c
#  dtype: str,
#  'a',
#  3    b
#  5    c
#  dtype: str)

# %%
f1_drivers_dict = {
    'max verstappen' : 4,
    'lewis hamilton' : 7,
    'charles leclerc' : 0
}
f1_drivers = pd.Series(f1_drivers_dict)
f1_drivers_dict, f1_drivers, f1_drivers['max verstappen'], f1_drivers["max verstappen":"charles leclerc"]
# Out:
# ({'max verstappen': 4, 'lewis hamilton': 7, 'charles leclerc': 0},
#  max verstappen     4
#  lewis hamilton     7
#  charles leclerc    0
#  dtype: int64,
#  np.int64(4),
#  max verstappen     4
#  lewis hamilton     7
#  charles leclerc    0
#  dtype: int64)

# %%
pd.Series(5, index=[100,200,300])
# Out:
# 100    5
# 200    5
# 300    5
# dtype: int64

# %%
pd.Series({2:'a', 1:'b', 3:'c'})
# Out:
# 2    a
# 1    b
# 3    c
# dtype: str

# %%
pd.Series({2:'a', 1:'b', 3:'c'}, index=[3,2])
# Out:
# 3    c
# 2    a
# dtype: str

# %% [markdown]
# DataFrame Object

# %% [markdown]
# <h4>If a Series is an analog of a one-dimensional array with flexible indices, a DataFrame is an analog of a two-dimensional array with both flexible row indices and flexible column names. </h4>

# %%
population_dict = {'California': 38332521,
                   'Texas': 26448193,
                   'New York': 19651127,
                   'Florida': 19552860,
                   'Illinois': 12882135}
population = pd.Series(population_dict)
population
# Out:
# California    38332521
# Texas         26448193
# New York      19651127
# Florida       19552860
# Illinois      12882135
# dtype: int64

# %%
area_dict = {'California': 423967, 
             'Texas': 695662, 
             'New York': 141297,
             'Florida': 170312, 
             'Illinois|s': 149995}
area = pd.Series(area_dict)
area
# Out:
# California    423967
# Texas         695662
# New York      141297
# Florida       170312
# Illinois|s    149995
# dtype: int64

# %%
states = pd.DataFrame({'population': population, 'area':area})
states
# Out:
#             population      area
# California  38332521.0  423967.0
# Florida     19552860.0  170312.0
# Illinois    12882135.0       NaN
# Illinois|s         NaN  149995.0
# New York    19651127.0  141297.0
# Texas       26448193.0  695662.0

# %%
states.index, states.columns
# Out:
# (Index(['California', 'Florida', 'Illinois', 'Illinois|s', 'New York', 'Texas'], dtype='str'),
#  Index(['population', 'area'], dtype='str'))

# %%
pd.DataFrame(population, columns=['population'])
# Out:
#             population
# California    38332521
# Texas         26448193
# New York      19651127
# Florida       19552860
# Illinois      12882135

# %%
'New York' in population
# Out:
# True

# %%
population.keys()
# Out:
# Index(['California', 'Texas', 'New York', 'Florida', 'Illinois'], dtype='str')

# %%
list(population.items())
# Out:
# [('California', 38332521),
#  ('Texas', 26448193),
#  ('New York', 19651127),
#  ('Florida', 19552860),
#  ('Illinois', 12882135)]

# %%
data = [{'A':i, 'B':2*i} for i in range(1,4)]
pd.DataFrame(data)
# Out:
#    A  B
# 0  1  2
# 1  2  4
# 2  3  6

# %%
pd.DataFrame([{'a':1, 'b':2}, {'b':3, 'c':4}])
# Out:
#      a  b    c
# 0  1.0  2  NaN
# 1  NaN  3  4.0

# %%
pd.DataFrame(np.random.rand(3,2),
             columns=['foo', 'bar'],
             index=['a', 'b', 'c']
)
# Out:
#         foo       bar
# a  0.974736  0.098474
# b  0.021108  0.073127
# c  0.112272  0.252928

# %%
A = np.zeros(3, dtype=[('A', 'i8'), ('B', 'f8')])
A
# Out:
# array([(0, 0.), (0, 0.), (0, 0.)], dtype=[('A', '<i8'), ('B', '<f8')])

# %%
pd.DataFrame(A)
# Out:
#    A    B
# 0  0  0.0
# 1  0  0.0
# 2  0  0.0

# %%
area = pd.Series({'California': 423967, 'Texas': 695662,
                  'New York': 141297, 'Florida': 170312,
                  'Illinois': 149995})
pop = pd.Series({'California': 38332521, 'Texas': 26448193,
                 'New York': 19651127, 'Florida': 19552860,
                 'Illinois': 12882135})
data = pd.DataFrame({'area':area, 'pop':pop})
data
# Out:
#               area       pop
# California  423967  38332521
# Texas       695662  26448193
# New York    141297  19651127
# Florida     170312  19552860
# Illinois    149995  12882135

# %%
data['density'] = data['pop'] / data['area']
data
# Out:
#               area       pop     density
# California  423967  38332521   90.413926
# Texas       695662  26448193   38.018740
# New York    141297  19651127  139.076746
# Florida     170312  19552860  114.806121
# Illinois    149995  12882135   85.883763

# %%
data.keys, data.values
# Out:
# (<bound method NDFrame.keys of               area       pop     density
#  California  423967  38332521   90.413926
#  Texas       695662  26448193   38.018740
#  New York    141297  19651127  139.076746
#  Florida     170312  19552860  114.806121
#  Illinois    149995  12882135   85.883763>,
#  array([[4.23967000e+05, 3.83325210e+07, 9.04139261e+01],
#         [6.95662000e+05, 2.64481930e+07, 3.80187404e+01],
#         [1.41297000e+05, 1.96511270e+07, 1.39076746e+02],
#         [1.70312000e+05, 1.95528600e+07, 1.14806121e+02],
#         [1.49995000e+05, 1.28821350e+07, 8.58837628e+01]]))

# %%
data.T
# Out:
#            California         Texas      New York       Florida      Illinois
# area     4.239670e+05  6.956620e+05  1.412970e+05  1.703120e+05  1.499950e+05
# pop      3.833252e+07  2.644819e+07  1.965113e+07  1.955286e+07  1.288214e+07
# density  9.041393e+01  3.801874e+01  1.390767e+02  1.148061e+02  8.588376e+01

# %%
data.loc[data.density > 100, ['pop', 'density']]
# Out:
#                pop     density
# New York  19651127  139.076746
# Florida   19552860  114.806121

# %% [markdown]
# <h3>Index Object</h3>

# %%
ind = pd.Index([1,2,3,4,5,6])
ind, ind[1], ind[::2]
# Out:
# (Index([1, 2, 3, 4, 5, 6], dtype='int64'),
#  np.int64(2),
#  Index([1, 3, 5], dtype='int64'))

# %%
ind.size, ind.shape, ind.ndim, ind.dtype
# Out:
# (6, (6,), 1, dtype('int64'))

# %% [markdown]
# TypeError("Index does not support mutable operations")

# %%
indA = pd.Index([1, 3, 5, 7, 9])
indB = pd.Index([2, 3, 5, 7, 11])
indA, indB
# Out:
# (Index([1, 3, 5, 7, 9], dtype='int64'), Index([2, 3, 5, 7, 11], dtype='int64'))

# %%
indA & indB, indA | indB, indA ^ indB
# Out:
# (Index([0, 3, 5, 7, 9], dtype='int64'),
#  Index([3, 3, 5, 7, 11], dtype='int64'),
#  Index([3, 0, 0, 0, 2], dtype='int64'))

# %%
rng = np.random.RandomState(42)
ser = pd.Series(rng.randint(0, 10, 4))
ser
# Out:
# 0    6
# 1    3
# 2    7
# 3    4
# dtype: int32

# %%
df = pd.DataFrame(rng.randint(0, 10, (3, 4)), columns=['A', 'B', 'C', 'D'])
df
# Out:
#    A  B  C  D
# 0  6  9  2  6
# 1  7  4  3  7
# 2  7  2  5  4

# %%
np.exp(ser)
# Out:
# 0     403.428793
# 1      20.085537
# 2    1096.633158
# 3      54.598150
# dtype: float64

# %%
np.sin(df * np.pi / 4)
# Out:
#           A             B         C             D
# 0 -1.000000  7.071068e-01  1.000000 -1.000000e+00
# 1 -0.707107  1.224647e-16  0.707107 -7.071068e-01
# 2 -0.707107  1.000000e+00 -0.707107  1.224647e-16

# %% [markdown]
# UFuncs: Index Alignment

# %%
area = pd.Series({'Alaska': 1723337, 'Texas': 695662, 'California': 423967}, name='area')
population = pd.Series({'California': 38332521, 'Texas': 26448193, 'New York': 19651127}, name='population')

# %%
population/area
# Out:
# Alaska              NaN
# California    90.413926
# New York            NaN
# Texas         38.018740
# dtype: float64

# %%
A = pd.Series([2, 4, 6], index=[0, 1, 2])
B = pd.Series([1, 3, 5], index=[1, 2, 3])
A + B
# Out:
# 0    NaN
# 1    5.0
# 2    9.0
# 3    NaN
# dtype: float64

# %%
A.add(B, fill_value=2)
# Out:
# 0    4.0
# 1    5.0
# 2    9.0
# 3    7.0
# dtype: float64

# %% [markdown]
# Index alignment in DataFrame

# %%
A = pd.DataFrame(rng.randint(0, 20, (2, 2)), columns=list('AB'))
A
# Out:
#     A   B
# 0   9   3
# 1  17  11

# %%
B = pd.DataFrame(rng.randint(0, 10, (3, 3)), columns=list('BAC'))
B
# Out:
#    B  A  C
# 0  1  9  3
# 1  7  6  8
# 2  7  4  1

# %%
A+B
# Out:
#       A     B   C
# 0  18.0   4.0 NaN
# 1  23.0  18.0 NaN
# 2   NaN   NaN NaN

# %%
fill = A.stack().mean()
A.add(B, fill_value=fill)
# Out:
#       A     B     C
# 0  18.0   4.0  13.0
# 1  23.0  18.0  18.0
# 2  14.0  17.0  11.0

# %%
for dtype in ['object', 'int']:
    print("dtype =", dtype)
    # %timeit np.arange(1E6, dtype=dtype).sum()
    print()
# Out:
# dtype = object
# 41.6 ms ± 1.46 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)
#
# dtype = int
# 2.57 ms ± 40.2 μs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
vals2 = np.array([1, np.nan, 3, 4]) 
vals2.dtype
# Out:
# dtype('float64')

# %%
1 + np.nan, 0 *  np.nan
# Out:
# (nan, nan)

# %%
pd.Series([1, np.nan, 2, None])
# Out:
# 0    1.0
# 1    NaN
# 2    2.0
# 3    NaN
# dtype: float64

# %% [markdown]
# Pandas automatically converts the None to a NaN value

# %%
data.isnull()
# Out:
#              area    pop  density
# California  False  False    False
# Texas       False  False    False
# New York    False  False    False
# Florida     False  False    False
# Illinois    False  False    False

# %%
data[data.notnull()]
# Out:
#               area       pop     density
# California  423967  38332521   90.413926
# Texas       695662  26448193   38.018740
# New York    141297  19651127  139.076746
# Florida     170312  19552860  114.806121
# Illinois    149995  12882135   85.883763

# %%
df = pd.DataFrame([1, None, 0, -2])
df.dropna()
# Out:
#      0
# 0  1.0
# 2  0.0
# 3 -2.0

# %%
df.dropna(axis='columns')
# Out:
# Empty DataFrame
# Columns: []
# Index: [0, 1, 2, 3]

# %%
data = pd.Series([1, np.nan, 2, None, 3], index=list('abcde'))
data
# Out:
# a    1.0
# b    NaN
# c    2.0
# d    NaN
# e    3.0
# dtype: float64

# %%
data.fillna(0)
# Out:
# a    1.0
# b    0.0
# c    2.0
# d    0.0
# e    3.0
# dtype: float64

# %%
# forward-fill
data.fillna(value=1)
# Out:
# a    1.0
# b    1.0
# c    2.0
# d    1.0
# e    3.0
# dtype: float64

# %%
index = [('California', 2000), ('California', 2010), ('New York', 2000), ('New York', 2010), ('Texas', 2000), ('Texas', 2010)]
index = pd.MultiIndex.from_tuples(index)
index
# Out:
# MultiIndex([('California', 2000),
#             ('California', 2010),
#             (  'New York', 2000),
#             (  'New York', 2010),
#             (     'Texas', 2000),
#             (     'Texas', 2010)],
#            )

# %%
pop = pop.reindex(index)
pop
# Out:
# California  2000   NaN
#             2010   NaN
# New York    2000   NaN
#             2010   NaN
# Texas       2000   NaN
#             2010   NaN
# dtype: float64

# %%
pop_df = pop.unstack()
pop_df
# Out:
#             2000  2010
# California   NaN   NaN
# New York     NaN   NaN
# Texas        NaN   NaN

# %%
pop_df.stack()
# Out:
# California  2000   NaN
#             2010   NaN
# New York    2000   NaN
#             2010   NaN
# Texas       2000   NaN
#             2010   NaN
# dtype: float64

# %%
pop_df = pd.DataFrame({'total': pop,
                       'under18': [9267089, 9284094,
                                   4687374, 4318033,
                                   5906301, 6879014]})
pop_df
# Out:
#                  total  under18
# California 2000    NaN  9267089
#            2010    NaN  9284094
# New York   2000    NaN  4687374
#            2010    NaN  4318033
# Texas      2000    NaN  5906301
#            2010    NaN  6879014

# %%
df = pd.DataFrame(np.random.rand(4, 2),
                  index=[['a', 'a', 'b', 'b'], [1, 2, 1, 2]],
                  columns=['data1', 'data2'])
df
# Out:
#         data1     data2
# a 1  0.370876  0.586639
#   2  0.993589  0.963314
# b 1  0.042006  0.064556
#   2  0.676757  0.223546

# %%
data = {('California', 2000): 33871648,
        ('California', 2010): 37253956,
        ('Texas', 2000): 20851820,
        ('Texas', 2010): 25145561,
        ('New York', 2000): 18976457,
        ('New York', 2010): 19378102}
pd.Series(data)
# Out:
# California  2000    33871648
#             2010    37253956
# Texas       2000    20851820
#             2010    25145561
# New York    2000    18976457
#             2010    19378102
# dtype: int64

# %%
pd.MultiIndex.from_arrays([['a', 'a', 'b', 'b'], [1, 2, 1, 2]])
# Out:
# MultiIndex([('a', 1),
#             ('a', 2),
#             ('b', 1),
#             ('b', 2)],
#            )

# %%
pd.MultiIndex.from_tuples([('a', 1), ('a', 2), ('b', 1), ('b', 2)])
# Out:
# MultiIndex([('a', 1),
#             ('a', 2),
#             ('b', 1),
#             ('b', 2)],
#            )

# %%
pd.MultiIndex.from_product([['a', 'b'], [1, 2]])
# Out:
# MultiIndex([('a', 1),
#             ('a', 2),
#             ('b', 1),
#             ('b', 2)],
#            )

# %%
pop
# Out:
# California  2000   NaN
#             2010   NaN
# New York    2000   NaN
#             2010   NaN
# Texas       2000   NaN
#             2010   NaN
# dtype: float64

# %%
pop.index.names = ['state', 'year']
pop
# Out:
# state       year
# California  2000   NaN
#             2010   NaN
# New York    2000   NaN
#             2010   NaN
# Texas       2000   NaN
#             2010   NaN
# dtype: float64

# %%
# hierarchical indices and columns
index = pd.MultiIndex.from_product([[2013, 2014], [1, 2]],
                                   names=['year', 'visit'])
columns = pd.MultiIndex.from_product([['Bob', 'Guido', 'Sue'], ['HR', 'Temp']],
                                     names=['subject', 'type'])

# mock some data
data = np.round(np.random.randn(4, 6), 1)
data[:, ::2] *= 10
data += 37

# create the DataFrame
health_data = pd.DataFrame(data, index=index, columns=columns)
health_data
# Out:
# subject      Bob       Guido         Sue
# type          HR  Temp    HR  Temp    HR  Temp
# year visit
# 2013 1      23.0  37.3  42.0  36.6  44.0  35.2
#      2      24.0  37.1  29.0  37.0  29.0  36.7
# 2014 1      36.0  36.0  43.0  37.8  39.0  36.4
#      2      28.0  35.4  25.0  37.2  28.0  35.7

# %%
health_data['Guido']
# Out:
# type          HR  Temp
# year visit
# 2013 1      42.0  36.6
#      2      29.0  37.0
# 2014 1      43.0  37.8
#      2      25.0  37.2

# %%
ser1 = pd.Series(['A', 'B', 'C'], index=[1, 2, 3])
ser2 = pd.Series(['D', 'E', 'F'], index=[4, 5, 6])
pd.concat([ser1, ser2])
# Out:
# 1    A
# 2    B
# 3    C
# 4    D
# 5    E
# 6    F
# dtype: str

# %%
df1 = pd.DataFrame({'employee': ['Bob', 'Jake', 'Lisa', 'Sue'],
                    'group': ['Accounting', 'Engineering', 'Engineering', 'HR']})
df2 = pd.DataFrame({'employee': ['Lisa', 'Bob', 'Jake', 'Sue'],
                    'hire_date': [2004, 2008, 2012, 2014]})
df1
# Out:
#   employee        group
# 0      Bob   Accounting
# 1     Jake  Engineering
# 2     Lisa  Engineering
# 3      Sue           HR

# %%
df2
# Out:
#   employee  hire_date
# 0     Lisa       2004
# 1      Bob       2008
# 2     Jake       2012
# 3      Sue       2014

# %%
df3 = pd.merge(df1,df2)
df3
# Out:
#   employee        group  hire_date
# 0      Bob   Accounting       2008
# 1     Jake  Engineering       2012
# 2     Lisa  Engineering       2004
# 3      Sue           HR       2014

# %%
rng = np.random.RandomState(42)
ser = pd.Series(rng.rand(5))
ser
# Out:
# 0    0.374540
# 1    0.950714
# 2    0.731994
# 3    0.598658
# 4    0.156019
# dtype: float64

# %%
ser.sum(), ser.mean()
# Out:
# (np.float64(2.811925491708157), np.float64(0.5623850983416314))

# %%
df = pd.DataFrame({'A': rng.rand(5), 'B': rng.rand(5)})
df
# Out:
#           A         B
# 0  0.155995  0.020584
# 1  0.058084  0.969910
# 2  0.866176  0.832443
# 3  0.601115  0.212339
# 4  0.708073  0.181825

# %%
df.mean(), df.mean(axis='columns')
# Out:
# (A    0.477888
#  B    0.443420
#  dtype: float64,
#  0    0.088290
#  1    0.513997
#  2    0.849309
#  3    0.406727
#  4    0.444949
#  dtype: float64)

# %% [markdown]
# Aggregation	Description
#
# count()	Total number of items
#
# first(), last()	First and last item
#
# mean(), median()	Mean and median
#
# min(), max()	Minimum and maximum
#
# std(), var()	Standard deviation and variance
#
# mad()	Mean absolute deviation
#
# prod()	Product of all items
#
# sum()	Sum of all items

# %%
df = pd.DataFrame({'key': ['A', 'B', 'C', 'A', 'B', 'C'], 'data': range(6)}, columns=['key', 'data'])
df
# Out:
#   key  data
# 0   A     0
# 1   B     1
# 2   C     2
# 3   A     3
# 4   B     4
# 5   C     5

# %%
df.groupby('key')

# %%
df.groupby('key').sum()
# Out:
#      data
# key
# A       3
# B       5
# C       7

# %%
rng = np.random.RandomState(0)
df = pd.DataFrame({'key': ['A', 'B', 'C', 'A', 'B', 'C'],
                   'data1': range(6),
                   'data2': rng.randint(0, 10, 6)},
                   columns = ['key', 'data1', 'data2'])
df
# Out:
#   key  data1  data2
# 0   A      0      5
# 1   B      1      0
# 2   C      2      3
# 3   A      3      3
# 4   B      4      7
# 5   C      5      9

# %%
df.groupby('key').aggregate(['min', np.median, max])
# Out:
#     data1            data2
#       min median max   min median max
# key
# A       0    1.5   3     3    4.0   5
# B       1    2.5   4     0    3.5   7
# C       2    3.5   5     3    6.0   9

# %%
df.groupby('key').aggregate({'data1': 'min', 'data2': 'max'})
# Out:
#      data1  data2
# key
# A        0      5
# B        1      7
# C        2      9

# %%
df.groupby('key').transform(lambda x: x - x.mean())
# Out:
#    data1  data2
# 0   -1.5    1.0
# 1   -1.5   -3.5
# 2   -1.5   -3.0
# 3    1.5   -1.0
# 4    1.5    3.5
# 5    1.5    3.0

# %% [markdown]
# Vectorized String Operations

# %%
data = ['peter', 'Paul', 'MARY', 'gUIDO']
[s.capitalize() for s in data]
# Out:
# ['Peter', 'Paul', 'Mary', 'Guido']

# %%
names = pd.Series(data)
names
# Out:
# 0    peter
# 1     Paul
# 2     MARY
# 3    gUIDO
# dtype: str

# %%
names.str.capitalize()
# Out:
# 0    Peter
# 1     Paul
# 2     Mary
# 3    Guido
# dtype: str

# %%
monte = pd.Series(['Graham Chapman', 'John Cleese', 'Terry Gilliam', 'Eric Idle', 'Terry Jones', 'Michael Palin'])
monte
# Out:
# 0    Graham Chapman
# 1       John Cleese
# 2     Terry Gilliam
# 3         Eric Idle
# 4       Terry Jones
# 5     Michael Palin
# dtype: str

# %% [markdown]
# len()	lower()	translate()	islower()
#
# ljust()	upper()	startswith()	isupper()
#
# rjust()	find()	endswith()	isnumeric()
#
# center()	rfind()	isalnum()	isdecimal()
#
# zfill()	index()	isalpha()	split()
#
# strip()	rindex()	isdigit()	rsplit()
#
# rstrip()	capitalize()	isspace()	partition()
#
# lstrip()	swapcase()	istitle()	rpartition()

# %%
monte.str.startswith('T')
# Out:
# 0    False
# 1    False
# 2     True
# 3    False
# 4     True
# 5    False
# dtype: bool

# %%
monte.str.split()
# Out:
# 0    [Graham, Chapman]
# 1       [John, Cleese]
# 2     [Terry, Gilliam]
# 3         [Eric, Idle]
# 4       [Terry, Jones]
# 5     [Michael, Palin]
# dtype: object

# %% [markdown]
# Method	Description
#
# match()	Call re.match() on each element, returning a boolean.
#
# extract()	Call re.match() on each element, returning matched groups as strings.
#
# findall()	Call re.findall() on each element
#
# replace()	Replace occurrences of pattern with some other string
#
# contains()	Call re.search() on each element, returning a boolean
#
# count()	Count occurrences of pattern
#
# split()	Equivalent to str.split(), but accepts regexps
#
# rsplit()	Equivalent to str.rsplit(), but accepts regexps

# %%
monte.str.extract('([A-Za-z]+)', expand=False)
# Out:
# 0     Graham
# 1       John
# 2      Terry
# 3       Eric
# 4      Terry
# 5    Michael
# dtype: str

# %%
monte.str.findall(r'^[^AEIOU].*[^aeiou]$')
# Out:
# 0    [Graham Chapman]
# 1                  []
# 2     [Terry Gilliam]
# 3                  []
# 4       [Terry Jones]
# 5     [Michael Palin]
# dtype: object

# %%
monte.str[0:3]
# Out:
# 0    Gra
# 1    Joh
# 2    Ter
# 3    Eri
# 4    Ter
# 5    Mic
# dtype: str

# %%
monte.str.split().str.get(-1)
# Out:
# 0    Chapman
# 1     Cleese
# 2    Gilliam
# 3       Idle
# 4      Jones
# 5      Palin
# dtype: object

# %%
from datetime import datetime
datetime(year=2006, month=5, day=1)
# Out:
# datetime.datetime(2006, 5, 1, 0, 0)

# %%
from dateutil import parser
date = parser.parse("1st of July, 2015")
date
# Out:
# datetime.datetime(2015, 7, 1, 0, 0)

# %%
date.strftime('%A')
# Out:
# 'Wednesday'

# %%
date = np.array('2015-07-04', dtype=np.datetime64)
date
# Out:
# array('2015-07-04', dtype='datetime64[D]')

# %%
date + np.arange(12)
# Out:
# array(['2015-07-04', '2015-07-05', '2015-07-06', '2015-07-07',
#        '2015-07-08', '2015-07-09', '2015-07-10', '2015-07-11',
#        '2015-07-12', '2015-07-13', '2015-07-14', '2015-07-15'],
#       dtype='datetime64[D]')

# %%
np.datetime64('2015-07-04 12:59:59.50', 'ns')
# Out:
# np.datetime64('2015-07-04T12:59:59.500000000')

# %%
index = pd.DatetimeIndex(['2014-07-04', '2014-08-04', '2015-07-04', '2015-08-04'])
data = pd.Series([0, 1, 2, 3], index=index)
data
# Out:
# 2014-07-04    0
# 2014-08-04    1
# 2015-07-04    2
# 2015-08-04    3
# dtype: int64

# %%
dates = pd.to_datetime([datetime(2015, 7, 3), '4th of July, 2015', '2015-Jul-6', '07-07-2015', '20150708'])
dates
# Out:
# DatetimeIndex(['2015-07-03', '2015-07-04', '2015-07-06', '2015-07-07',
#                '2015-07-08'],
#               dtype='datetime64[us]', freq=None)

# %%
pd.date_range('2015-07-03', '2015-07-10')
# Out:
# DatetimeIndex(['2015-07-03', '2015-07-04', '2015-07-05', '2015-07-06',
#                '2015-07-07', '2015-07-08', '2015-07-09', '2015-07-10'],
#               dtype='datetime64[us]', freq='D')

# %%
pd.date_range('2015-07-03', periods=8)
# Out:
# DatetimeIndex(['2015-07-03', '2015-07-04', '2015-07-05', '2015-07-06',
#                '2015-07-07', '2015-07-08', '2015-07-09', '2015-07-10'],
#               dtype='datetime64[us]', freq='D')

# %%
nrows, ncols = 100000, 100
rng = np.random.RandomState(42)
df1, df2, df3, df4 = (pd.DataFrame(rng.rand(nrows, ncols)) for i in range(4))
df1, df2, df3, df4
# Out:
# (             0         1         2         3         4         5         6   \
#  0      0.374540  0.950714  0.731994  0.598658  0.156019  0.155995  0.058084
#  1      0.031429  0.636410  0.314356  0.508571  0.907566  0.249292  0.410383
#  2      0.642032  0.084140  0.161629  0.898554  0.606429  0.009197  0.101472
#  3      0.051682  0.531355  0.540635  0.637430  0.726091  0.975852  0.516300
#  4      0.103124  0.902553  0.505252  0.826457  0.320050  0.895523  0.389202
#  ...         ...       ...       ...       ...       ...       ...       ...
#  99995  0.071979  0.439323  0.188588  0.586705  0.640611  0.662409  0.318503
#  99996  0.313411  0.010490  0.469216  0.600825  0.451085  0.496918  0.983128
#  99997  0.560873  0.647396  0.043068  0.282439  0.042950  0.346690  0.954034
#  99998  0.710115  0.067999  0.611329  0.136199  0.054724  0.018160  0.911428
#  99999  0.116834  0.461155  0.754556  0.250272  0.864631  0.588966  0.358260
#
#               7         8         9   ...        90        91        92  \
#  0      0.866176  0.601115  0.708073  ...  0.119594  0.713245  0.760785
#  1      0.755551  0.228798  0.076980  ...  0.093103  0.897216  0.900418
#  2      0.663502  0.005062  0.160808  ...  0.030500  0.037348  0.822601
#  99996  0.647074  0.671423  0.921422  0.450065  0.909240  0.317553  0.169943
#  99997  0.929684  0.563298  0.089244  0.281686  0.746781  0.412429  0.352413
#  99998  0.654283  0.528957  0.669479  0.036532  0.716870  0.264882  0.557014
#  99999  0.486491  0.944669  0.672019  0.101245  0.799393  0.795580  0.571488
#
#  [100000 rows x 100 columns])

# %%
# %timeit df1 + df2 + df3 + df4
# Out:
# 86.1 ms ± 4.26 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %%
# %timeit pd.eval('df1 + df2 + df3 + df4')
# Out:
# 89.4 ms ± 4.72 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %%
df1, df2, df3, df4, df5 = (pd.DataFrame(rng.randint(0, 1000, (100, 3))) for i in range(5))

# %%
df.values.nbytes
# Out:
# 144

# %%
data
# Out:
# 2014-07-04    0
# 2014-08-04    1
# 2015-07-04    2
# 2015-08-04    3
# dtype: int64

# %%
df_13 = pd.DataFrame({'foo' : [7, -5, 7, 4, 2, 0, 4, 7],
                   'bar' : [-5, 4, 2, 0, 4, 7, 7, 8],
                   'baz' : [-1, 2, 3, 0, 5, 9, 9, 5]})
df_13
# Out:
#    foo  bar  baz
# 0    7   -5   -1
# 1   -5    4    2
# 2    7    2    3
# 3    4    0    0
# 4    2    4    5
# 5    0    7    9
# 6    4    7    9
# 7    7    8    5

# %%
df_13.rank()
# Out:
#    foo  bar  baz
# 0  7.0  1.0  1.0
# 1  1.0  4.5  3.0
# 2  7.0  3.0  4.0
# 3  4.5  2.0  2.0
# 4  3.0  4.5  5.5
# 5  2.0  6.5  7.5
# 6  4.5  6.5  7.5
# 7  7.0  8.0  5.5

# %%
df_13.rank(axis=1)
# Out:
#    foo  bar  baz
# 0  3.0  1.0  2.0
# 1  1.0  3.0  2.0
# 2  3.0  1.0  2.0
# 3  3.0  1.5  1.5
# 4  1.0  2.0  3.0
# 5  1.0  2.0  3.0
# 6  1.0  2.0  3.0
# 7  2.0  3.0  1.0

# %% [markdown]
# <h2>scikit learn</h2>

# %%
from sklearn.datasets import load_iris
iris = load_iris()

# %%
iris.data.shape, iris.keys, iris.target.shape, iris.target_names, iris.feature_names
# Out:
# ((150, 4),
#  <function Bunch.keys>,
#  (150,),
#  array(['setosa', 'versicolor', 'virginica'], dtype='<U10'),
#  ['sepal length (cm)',
#   'sepal width (cm)',
#   'petal length (cm)',
#   'petal width (cm)'])

# %% [markdown]
# K-Nearest Neighbors Classifier

# %%
import numpy as np
import sklearn

print(np.__version__)
print(sklearn.__version__)
# Out:
# 2.4.6
# 1.9.0

# %%
from sklearn import neighbors, datasets

iris = datasets.load_iris()
X, y = iris.data, iris.target

# create the model
knn = neighbors.KNeighborsClassifier(n_neighbors=5, weights='uniform')

# fit the model
knn.fit(X, y)

# What kind of iris has 3cm x 5cm sepal and 4cm x 2cm petal?
X_pred = [3, 5, 4, 2]
result = knn.predict([X_pred, ])

print(iris.target_names[result])
print(iris.target_names)
print(knn.predict_proba([X_pred, ]))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[15], line 10
#       6 # create the model
#       7 knn = neighbors.KNeighborsClassifier(n_neighbors=5, weights='uniform')
#       8
#       9 # fit the model
# ---> 10 knn.fit(X, y)
#      11
#      12 # What kind of iris has 3cm x 5cm sepal and 4cm x 2cm petal?
#      13 X_pred = [3, 5, 4, 2]
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:1403, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1393     estimator._validate_params()
#    1395 with (
#    1396     config_context(
#    1397         skip_parameter_validation=(
#    (...)   1401     callback_management_context(estimator),
#    1402 ):
# -> 1403     return fit_method(estimator, *args, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\neighbors\_classification.py:243, in KNeighborsClassifier.fit(self, X, y)
#     221 @_fit_context(
#     222     # KNeighborsClassifier.metric is not validated yet
#     223     prefer_skip_nested_validation=False
#     224 )
#     225 def fit(self, X, y):
#     226     """Fit the k-nearest neighbors classifier from the training dataset.
#     227
#     228     Parameters
#    (...)    241         The fitted k-nearest neighbors classifier.
#     242     """
# --> 243     return self._fit(X, y)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\neighbors\_base.py:501, in NeighborsBase._fit(self, X, y)
#     498 else:
#     499     self.outputs_2d_ = True
# --> 501 check_classification_targets(y)
#     502 self.classes_ = []
#     503 # Using `dtype=np.intp` is necessary since `np.bincount`
#     504 # (called in _classification.py) fails when dealing
#     505 # with a float64 array on 32bit systems.
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\multiclass.py:222, in check_classification_targets(y)
#     210 def check_classification_targets(y):
#     211     """Ensure that target y is of a non-regression type.
#     212
#     213     Only the following target types (as defined in type_of_target) are allowed:
#    (...)    220         Target values.
#     221     """
# --> 222     y_type = type_of_target(y, input_name="y")
#     223     if y_type not in [
#     224         "binary",
#     225         "multiclass",
#    (...)    228         "multilabel-sequences",
#     229     ]:
#     230         raise ValueError(
#     231             f"Unknown label type: {y_type}. Maybe you are trying to fit a "
#     232             "classifier, which expects discrete classes on a "
#     233             "regression target with continuous values."
#     234         )
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\multiclass.py:441, in type_of_target(y, input_name, raise_unknown)
#     439 if issparse(first_row_or_val):
#     440     first_row_or_val = first_row_or_val.data
# --> 441 if cached_unique(y).shape[0] > 2 or (y.ndim == 2 and len(first_row_or_val) > 1):
#     442     # [1, 2, 3] or [[1., 2., 3]] or [[1, 2]]
#     443     return "multiclass" + suffix
#     444 else:
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\_unique.py:105, in cached_unique(xp, *ys)
#      81 def cached_unique(*ys, xp=None):
#      82     """Return the unique values of ys.
#      83
#      84     Use the cached values from dtype.metadata if present.
#    (...)    103         Unique values of ys.
#     104     """
# --> 105     res = tuple(_cached_unique(y, xp=xp) for y in ys)
#     106     if len(res) == 1:
#     107         return res[0]
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\_unique.py:105, in <genexpr>(.0)
#      81 def cached_unique(*ys, xp=None):
#      82     """Return the unique values of ys.
#      83
#      84     Use the cached values from dtype.metadata if present.
#    (...)    103         Unique values of ys.
#     104     """
# --> 105     res = tuple(_cached_unique(y, xp=xp) for y in ys)
#     106     if len(res) == 1:
#     107         return res[0]
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\_unique.py:78, in _cached_unique(y, xp)
#      76     pass
#      77 xp, _ = get_namespace(y, xp=xp)
# ---> 78 return xp.unique_values(y)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\externals\array_api_compat\_internal.py:35, in get_xp.<locals>.inner.<locals>.wrapped_f(*args, **kwargs)
#      33 @wraps(f)
#      34 def wrapped_f(*args: object, **kwargs: object) -> object:
# ---> 35     return f(*args, xp=xp, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\externals\array_api_compat\common\_aliases.py:256, in unique_values(x, xp)
#     254 def unique_values(x: Array, /, xp: Namespace) -> Array:
#     255     kwargs = _unique_kwargs(xp)
# --> 256     return xp.unique(
#     257         x,
#     258         return_counts=False,
#     259         return_index=False,
#     260         return_inverse=False,
#     261         **kwargs,
#     262     )
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\numpy\lib\_arraysetops_impl.py:296, in unique(ar, return_index, return_inverse, return_counts, axis, equal_nan, sorted)
#     294     if axis is not None:
#     295         normalize_axis_index(axis, ar.ndim)
# --> 296     ret = _unique1d(ar, return_index, return_inverse, return_counts,
#     297                     equal_nan=equal_nan, inverse_shape=ar.shape, axis=None,
#     298                     sorted=sorted)
#     299     return _unpack_tuple(ret)
#     301 # axis was specified and not None
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\numpy\lib\_arraysetops_impl.py:373, in _unique1d(ar, return_index, return_inverse, return_counts, equal_nan, inverse_shape, axis, sorted)
#     370 conv = _array_converter(ar)
#     371 ar_, = conv
# --> 373 if (hash_unique := _unique_hash(ar_, equal_nan=equal_nan)) \
#     374     is not NotImplemented:
#     375     if sorted:
#     376         hash_unique.sort()
#
# TypeError: numpy._core._multiarray_umath._unique_hash() takes no keyword arguments
